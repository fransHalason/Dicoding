# %%
a = 10
print(a, "bertipe", type(a))
b = 1.7
print(b, "bertipe", type(b))
c= 1+3j
print(c, "bertipe", type(c), "adalah", isinstance(1+3j,complex))
# Out:
# 10 bertipe <class 'int'>
# 1.7 bertipe <class 'float'>
# (1+3j) bertipe <class 'complex'> adalah True

# %%
x=[0]*10005;    #insialisasi array 0 sebanyak 10005; x[0]=0
x[1]=1;

for j in range(2,10001):
    x[j]=x[j-1]+x[j-2]  # Fibonacci
print(x[10000])
# Out:
# ...

# %%
b = 0.12345678901234567890
print(b)
# Out:
# 0.12345678901234568

# %%
a = 12345678901234567890
print(a)
# Out:
# 12345678901234567890

# %%
c = 1+5j
print(c)
# Out:
# (1+5j)
